# %% [markdown]
# # Chart 3: Employment Rate by Migration Category & Years in Sweden
#
# ## Data Source
# **Statistics Sweden (SCB)** — Integration Statistics (Register-based)
#
# | Field | Value |
# |-------|-------|
# | Table | Number in population by employment status, grounds for settlement, number of years in Sweden, region of birth, sex, age and year |
# | URL | https://www.statistikdatabasen.scb.se/pxweb/en/ssd/START__AA__AA0003__AA0003B/ |
# | Coverage | 2020–2023 (annual) |
# | Unit | Number of persons → converted to employment rate (%) |
#
# ## How to Replicate (Download from SCB)
# 1. Go to: https://www.statistikdatabasen.scb.se/pxweb/en/ssd/START__AA__AA0003__AA0003B/
# 2. Select table: **Persons aged 20-74 by occupation, grounds for settlement, number of years in Sweden, region of birth, sex and age**
# 3. Choose variables:
#    - **employment status**: select `total` and `gainfully employed population`
#    - **grounds for settlement**: select ALL
#    - **number of years in Sweden**: select ALL
#    - **region of birth**: select `total`
#    - **sex**: select `total`
#    - **age**: select `total`
#    - **year**: select ALL (2020-2023)
# 4. Click **Continue**
# 5. Download as: **CSV with heading**
# 6. Save as `p3_raw.csv`
#
# ## Output
# Heat map data showing employment rate by:
# - **Rows**: Migration category (Labour, Refugee, Family, Other)
# - **Columns**: Years in Sweden (0-3, 4-9, 10+)
# - **Color**: Employment rate (%)

# %%
import pandas as pd
import json

print("Libraries loaded successfully")
# Out:
# Libraries loaded successfully

# %%
# Load data directly from GitHub, or replicate using instructions above
DATA_URL = "https://raw.githubusercontent.com/kelvinchwng/kelvinchwng.github.io/main/project/data/p3_raw.csv"

# Skip the title row (row 0), use row 1 as header
df_raw = pd.read_csv(DATA_URL, encoding='utf-8', skiprows=1)

print(f"Loaded from: {DATA_URL}")
print(f"Shape: {df_raw.shape}")
print(f"\nColumns: {df_raw.columns.tolist()}")

# Preview the data
df_raw.head(10)
# Out:
# Loaded from: https://raw.githubusercontent.com/kelvinchwng/kelvinchwng.github.io/main/project/data/p3_raw.csv
# Shape: (6804, 10)
#
# Columns: ['employment status', 'grounds for settlement', 'number of years in Sweden', 'region of birth', 'sex', 'age', '2020', '2021', '2022', '2023']
#   employment status grounds for settlement number of years in Sweden  \
# 0             total                  total                     total
# 1             total                  total                     total
# 2             total                  total                     total
# 3             total                  total                     total
# 4             total                  total                     total
# 5             total                  total                     total
# 6             total                  total                     total
# 7             total                  total                     total
# 8             total                  total                     total
# 9             total                  total                     total
#
#   region of birth    sex          age     2020     2021     2022     2023
# 0           total  total        total  6964186  6979822  7009602  7019050
# 1           total  total  20-24 years   579464   578214   585492   591869
# 2           total  total  25-29 years   717758   692315   666652   642641
# 3           total  total  30-39 years  1398677  1437787  1475318  1496129
# 4           total  total  40-49 years  1301464  1299227  1300728  1299753
# 5           total  total  50-59 years  1310242  1326134  1339202  1343104
# 6           total  total  60-64 years   569227   569806   575089   587195
# 7           total  total  65-69 years   536735   540223   542741   543719
# 8           total  total  70-74 years   550616   536117   524385   514636
# 9          Sweden  total        total  5301126  5273091  5250604  5232057

# %%
# Check unique values for key columns
print("Employment status values:")
print(df_raw['employment status'].unique())

print("\nGrounds for settlement values:")
print(df_raw['grounds for settlement'].unique())

print("\nNumber of years in Sweden values:")
print(df_raw['number of years in Sweden'].unique())
# Out:
# Employment status values:
# ['total' 'not gainfully employed population'
#  'gainfully employed population']
#
# Grounds for settlement values:
# ['total' 'relatives - not refugees' 'labour market/students'
#  'refugees/persons in need of subsidiary protection/relatives '
#  'other/GFS not relevant' 'data not available']
#
# Number of years in Sweden values:
# ['total' 'born in Sweden' '0-3 years' '4-9 years' '10- years'
#  'data not available']

# %%
# Filter for what we need:
# - Total population and employed population
# - Specific grounds for settlement (not 'total' or 'data not available')
# - Specific years in Sweden (not 'total' or 'born in Sweden' or 'data not available')
# - Total for region, sex, age

# Define the categories we want
settlement_categories = [
    'labour market/students',
    'refugees/persons in need of subsidiary protection/relatives ',  # Note trailing space
    'relatives - not refugees',
    'other/GFS not relevant'
]

years_categories = ['0-3 years', '4-9 years', '10- years']

# Filter the dataframe
df_filtered = df_raw[
    (df_raw['grounds for settlement'].isin(settlement_categories)) &
    (df_raw['number of years in Sweden'].isin(years_categories)) &
    (df_raw['region of birth'] == 'total') &
    (df_raw['sex'] == 'total') &
    (df_raw['age'] == 'total')
].copy()

print(f"Filtered shape: {df_filtered.shape}")
df_filtered.head(20)
# Out:
# Filtered shape: (36, 10)
#                       employment status  \
# 504                               total
# 567                               total
# 630                               total
# 882                               total
# 945                               total
# 1008                              total
# 1260                              total
# 1323                              total
# 1386                              total
# 1638                              total
# 1701                              total
# 1764                              total
# 2772  not gainfully employed population
# 2835  not gainfully employed population
# 2898  not gainfully employed population
# 3150  not gainfully employed population
# 3213  not gainfully employed population
# 3276  not gainfully employed population
# 3528  not gainfully employed population
# 3591  not gainfully employed population
#
#                                  grounds for settlement  \
# 504                            relatives - not refugees
# 567                            relatives - not refugees
# 630                            relatives - not refugees
# 882                              labour market/students
# 945                              labour market/students
# 1008                             labour market/students
# 1260  refugees/persons in need of subsidiary protect...
# 1323  refugees/persons in need of subsidiary protect...
# 1386  refugees/persons in need of subsidiary protect...
# 1638                             other/GFS not relevant
# 1701                             other/GFS not relevant
# 1764                             other/GFS not relevant
# 2772                           relatives - not refugees
# 2835                           relatives - not refugees
# 2898                           relatives - not refugees
# 3150                             labour market/students
# 3213                             labour market/students
# 3276                             labour market/students
# 3528  refugees/persons in need of subsidiary protect...
# 3591  refugees/persons in need of subsidiary protect...
#
#      number of years in Sweden region of birth    sex    age    2020    2021  \
# 504                  0-3 years           total  total  total   56858   55896
# 567                  4-9 years           total  total  total   93221   90189
# 630                  10- years           total  total  total  168535  186204
# 882                  0-3 years           total  total  total   49170   50897
# 945                  4-9 years           total  total  total   43174   42450
# 1008                 10- years           total  total  total   43987   51600
# 1260                 0-3 years           total  total  total   75144   52727
# 1323                 4-9 years           total  total  total  179930  204601
# 1386                 10- years           total  total  total  352337  364291
# 1638                 0-3 years           total  total  total   10987   15408
# 1701                 4-9 years           total  total  total   10329   13311
# 1764                 10- years           total  total  total  130207  132402
# 2772                 0-3 years           total  total  total   35557   33222
# 2835                 4-9 years           total  total  total   36654   33426
# 2898                 10- years           total  total  total   52858   54983
# 3150                 0-3 years           total  total  total   16830   16760
# 3213                 4-9 years           total  total  total   12274   11780
# 3276                 10- years           total  total  total   11086   12799
# 3528                 0-3 years           total  total  total   50929   33216
# 3591                 4-9 years           total  total  total   87330   88872
#
#         2022    2023
# 504    55123   53106
# 567    86557   84961
# 630   205647  220682
# 882    52912   50652
# 945    45388   45730
# 1008   58714   63028
# 1260   37164   26843
# 1323  216923  209047
# 1386  379500  404979
# 1638   14675   12092
# 1701   16945   20042
# 1764  134198  135466
# 2772   31027   30910
# 2835   30390   29705
# 2898   57673   61893
# 3150   16914   14176
# 3213   12679   10005
# 3276   14304   14540
# 3528   23078   17848
# 3591   84335   78956

# %%
# Reshape: we need to calculate employment rate = employed / total * 100
# First, let's pivot to get total and employed side by side

# Melt the year columns into rows
year_cols = ['2020', '2021', '2022', '2023']
df_melted = df_filtered.melt(
    id_vars=['employment status', 'grounds for settlement', 'number of years in Sweden'],
    value_vars=year_cols,
    var_name='year',
    value_name='count'
)

print(f"Melted shape: {df_melted.shape}")
df_melted.head(10)
# Out:
# Melted shape: (144, 5)
#   employment status                             grounds for settlement  \
# 0             total                           relatives - not refugees
# 1             total                           relatives - not refugees
# 2             total                           relatives - not refugees
# 3             total                             labour market/students
# 4             total                             labour market/students
# 5             total                             labour market/students
# 6             total  refugees/persons in need of subsidiary protect...
# 7             total  refugees/persons in need of subsidiary protect...
# 8             total  refugees/persons in need of subsidiary protect...
# 9             total                             other/GFS not relevant
#
#   number of years in Sweden  year   count
# 0                 0-3 years  2020   56858
# 1                 4-9 years  2020   93221
# 2                 10- years  2020  168535
# 3                 0-3 years  2020   49170
# 4                 4-9 years  2020   43174
# 5                 10- years  2020   43987
# 6                 0-3 years  2020   75144
# 7                 4-9 years  2020  179930
# 8                 10- years  2020  352337
# 9                 0-3 years  2020   10987

# %%
# Pivot to get 'total' and 'gainfully employed population' as columns
df_pivot = df_melted.pivot_table(
    index=['grounds for settlement', 'number of years in Sweden', 'year'],
    columns='employment status',
    values='count',
    aggfunc='first'
).reset_index()

print(f"Pivot shape: {df_pivot.shape}")
print(f"Columns: {df_pivot.columns.tolist()}")
df_pivot.head(10)
# Out:
# Pivot shape: (48, 6)
# Columns: ['grounds for settlement', 'number of years in Sweden', 'year', 'gainfully employed population', 'not gainfully employed population', 'total']
# employment status  grounds for settlement number of years in Sweden  year  \
# 0                  labour market/students                 0-3 years  2020
# 1                  labour market/students                 0-3 years  2021
# 2                  labour market/students                 0-3 years  2022
# 3                  labour market/students                 0-3 years  2023
# 4                  labour market/students                 10- years  2020
# 5                  labour market/students                 10- years  2021
# 6                  labour market/students                 10- years  2022
# 7                  labour market/students                 10- years  2023
# 8                  labour market/students                 4-9 years  2020
# 9                  labour market/students                 4-9 years  2021
#
# employment status  gainfully employed population  \
# 0                                          32338
# 1                                          34138
# 2                                          35999
# 3                                          36475
# 4                                          32899
# 5                                          38802
# 6                                          44413
# 7                                          48488
# 8                                          30899
# 9                                          30668
#
# employment status  not gainfully employed population  total
# 0                                              16830  49170
# 1                                              16760  50897
# 2                                              16914  52912
# 3                                              14176  50652
# 4                                              11086  43987
# 5                                              12799  51600
# 6                                              14304  58714
# 7                                              14540  63028
# 8                                              12274  43174
# 9                                              11780  42450

# %%
# Calculate employment rate
df_pivot['employment_rate'] = (df_pivot['gainfully employed population'] / df_pivot['total'] * 100).round(1)

# Clean up column names
df_pivot = df_pivot.rename(columns={
    'grounds for settlement': 'category',
    'number of years in Sweden': 'years_in_sweden'
})

# Clean up category names for display
category_mapping = {
    'labour market/students': 'Labour migrants',
    'refugees/persons in need of subsidiary protection/relatives ': 'Refugees & relatives',
    'relatives - not refugees': 'Family reunion',
    'other/GFS not relevant': 'Other'
}

years_mapping = {
    '0-3 years': '0-3 yrs',
    '4-9 years': '4-9 yrs',
    '10- years': '10+ yrs'
}

df_pivot['category'] = df_pivot['category'].map(category_mapping)
df_pivot['years_in_sweden'] = df_pivot['years_in_sweden'].map(years_mapping)

df_pivot.head(20)
# Out:
# employment status         category years_in_sweden  year  \
# 0                  Labour migrants         0-3 yrs  2020
# 1                  Labour migrants         0-3 yrs  2021
# 2                  Labour migrants         0-3 yrs  2022
# 3                  Labour migrants         0-3 yrs  2023
# 4                  Labour migrants         10+ yrs  2020
# 5                  Labour migrants         10+ yrs  2021
# 6                  Labour migrants         10+ yrs  2022
# 7                  Labour migrants         10+ yrs  2023
# 8                  Labour migrants         4-9 yrs  2020
# 9                  Labour migrants         4-9 yrs  2021
# 10                 Labour migrants         4-9 yrs  2022
# 11                 Labour migrants         4-9 yrs  2023
# 12                           Other         0-3 yrs  2020
# 13                           Other         0-3 yrs  2021
# 14                           Other         0-3 yrs  2022
# 15                           Other         0-3 yrs  2023
# 16                           Other         10+ yrs  2020
# 17                           Other         10+ yrs  2021
# 18                           Other         10+ yrs  2022
# 19                           Other         10+ yrs  2023
#
# employment status  gainfully employed population  \
# 0                                          32338
# 1                                          34138
# 2                                          35999
# 3                                          36475
# 4                                          32899
# 5                                          38802
# 6                                          44413
# 7                                          48488
# 8                                          30899
# 9                                          30668
# 10                                         32710
# 11                                         35722
# 12                                          5513
# 13                                          8933
# 14                                          8290
# 15                                          7327
# 16                                         97282
# 17                                        101189
# 18                                        104485
# 19                                        105430
#
# employment status  not gainfully employed population   total  employment_rate
# 0                                              16830   49170             65.8
# 1                                              16760   50897             67.1
# 2                                              16914   52912             68.0
# 3                                              14176   50652             72.0
# 4                                              11086   43987             74.8
# 5                                              12799   51600             75.2
# 6                                              14304   58714             75.6
# 7                                              14540   63028             76.9
# 8                                              12274   43174             71.6
# 9                                              11780   42450             72.2
# 10                                             12679   45388             72.1
# 11                                             10005   45730             78.1
# 12                                              5478   10987             50.2
# 13                                              6469   15408             58.0
# 14                                              6384   14675             56.5
# 15                                              4767   12092             60.6
# 16                                             32927  130207             74.7
# 17                                             31218  132402             76.4
# 18                                             29714  134198             77.9
# 19                                             30035  135466             77.8

# %%
# For the heat map, we'll use the most recent year (2023)

df_heatmap = df_pivot[['category', 'years_in_sweden', 'year', 'employment_rate']].copy()
df_heatmap['year'] = df_heatmap['year'].astype(int)

print(f"Final shape: {df_heatmap.shape}")
print(f"\nYear range: {df_heatmap['year'].min()} - {df_heatmap['year'].max()}")
print(f"\nCategories: {df_heatmap['category'].unique().tolist()}")
print(f"\nYears in Sweden: {df_heatmap['years_in_sweden'].unique().tolist()}")

df_heatmap
# Out:
# Final shape: (48, 4)
#
# Year range: 2020 - 2023
#
# Categories: ['Labour migrants', 'Other', 'Refugees & relatives', 'Family reunion']
#
# Years in Sweden: ['0-3 yrs', '10+ yrs', '4-9 yrs']
# employment status              category years_in_sweden  year  employment_rate
# 0                       Labour migrants         0-3 yrs  2020             65.8
# 1                       Labour migrants         0-3 yrs  2021             67.1
# 2                       Labour migrants         0-3 yrs  2022             68.0
# 3                       Labour migrants         0-3 yrs  2023             72.0
# 4                       Labour migrants         10+ yrs  2020             74.8
# 5                       Labour migrants         10+ yrs  2021             75.2
# 6                       Labour migrants         10+ yrs  2022             75.6
# 7                       Labour migrants         10+ yrs  2023             76.9
# 8                       Labour migrants         4-9 yrs  2020             71.6
# 9                       Labour migrants         4-9 yrs  2021             72.2
# 10                      Labour migrants         4-9 yrs  2022             72.1
# 11                      Labour migrants         4-9 yrs  2023             78.1
# 12                                Other         0-3 yrs  2020             50.2
# 13                                Other         0-3 yrs  2021             58.0
# 14                                Other         0-3 yrs  2022             56.5
# 15                                Other         0-3 yrs  2023             60.6
# 16                                Other         10+ yrs  2020             74.7
# 17                                Other         10+ yrs  2021             76.4
# 18                                Other         10+ yrs  2022             77.9
# 19                                Other         10+ yrs  2023             77.8
# 20                                Other         4-9 yrs  2020             66.6
# 21                                Other         4-9 yrs  2021             73.4
# 22                                Other         4-9 yrs  2022             76.1
# 23                                Other         4-9 yrs  2023             76.4
# 24                 Refugees & relatives         0-3 yrs  2020             32.2
# 25                 Refugees & relatives         0-3 yrs  2021             37.0
# 26                 Refugees & relatives         0-3 yrs  2022             37.9
# 27                 Refugees & relatives         0-3 yrs  2023             33.5
# 28                 Refugees & relatives         10+ yrs  2020             64.8
# 29                 Refugees & relatives         10+ yrs  2021             66.3
# 30                 Refugees & relatives         10+ yrs  2022             67.7
# 31                 Refugees & relatives         10+ yrs  2023             67.6
# 32                 Refugees & relatives         4-9 yrs  2020             51.5
# 33                 Refugees & relatives         4-9 yrs  2021             56.6
# 34                 Refugees & relatives         4-9 yrs  2022             61.1
# 35                 Refugees & relatives         4-9 yrs  2023             62.2
# 36                       Family reunion         0-3 yrs  2020             37.5
# 37                       Family reunion         0-3 yrs  2021             40.6
# 38                       Family reunion         0-3 yrs  2022             43.7
# 39                       Family reunion         0-3 yrs  2023             41.8
# 40                       Family reunion         10+ yrs  2020             68.6
# 41                       Family reunion         10+ yrs  2021             70.5
# 42                       Family reunion         10+ yrs  2022             72.0
# 43                       Family reunion         10+ yrs  2023             72.0
# 44                       Family reunion         4-9 yrs  2020             60.7
# 45                       Family reunion         4-9 yrs  2021             62.9
# 46                       Family reunion         4-9 yrs  2022             64.9
# 47                       Family reunion         4-9 yrs  2023             65.0

# %%
# Preview the 2023 data (what the heat map will show by default)
df_2023 = df_heatmap[df_heatmap['year'] == 2023].pivot(
    index='category',
    columns='years_in_sweden',
    values='employment_rate'
)

# Reorder columns
df_2023 = df_2023[['0-3 yrs', '4-9 yrs', '10+ yrs']]

print("Employment Rate by Category and Years in Sweden (2023):")
print("="*60)
df_2023
# Out:
# Employment Rate by Category and Years in Sweden (2023):
# ============================================================
# years_in_sweden       0-3 yrs  4-9 yrs  10+ yrs
# category
# Family reunion           41.8     65.0     72.0
# Labour migrants          72.0     78.1     76.9
# Other                    60.6     76.4     77.8
# Refugees & relatives     33.5     62.2     67.6

# %%
# Export to JSON
output_filename = 'p3_data.json'

# Convert to records format for Vega-Lite
records = df_heatmap.to_dict(orient='records')

with open(output_filename, 'w') as f:
    json.dump(records, f, indent=2)

print(f"Exported {len(records)} records to {output_filename}")
print(f"\nJSON structure:")
print(json.dumps(records[:6], indent=2))
# Out:
# Exported 48 records to p3_data.json
#
# JSON structure:
# [
#   {
#     "category": "Labour migrants",
#     "years_in_sweden": "0-3 yrs",
#     "year": 2020,
#     "employment_rate": 65.8
#   },
#   {
#     "category": "Labour migrants",
#     "years_in_sweden": "0-3 yrs",
#     "year": 2021,
#     "employment_rate": 67.1
#   },
#   {
#     "category": "Labour migrants",
#     "years_in_sweden": "0-3 yrs",
#     "year": 2022,
#     "employment_rate": 68.0
#   },
#   {
#     "category": "Labour migrants",
#     "years_in_sweden": "0-3 yrs",
#     "year": 2023,
#     "employment_rate": 72.0
#   },
#   {
#     "category": "Labour migrants",
#     "years_in_sweden": "10+ yrs",
#     "year": 2020,
#     "employment_rate": 74.8
#   },
#   {
#     "category": "Labour migrants",
#     "years_in_sweden": "10+ yrs",
#     "year": 2021,
#     "employment_rate": 75.2
#   }
# ]

# %%
# Download
from google.colab import files
files.download(output_filename)

print(f"\nDownloaded: {output_filename}")
# Out:
# Downloaded: p3_data.json

# %% [markdown]
# ---
# ## Summary
#
# ### Data Pipeline
# ```
# SCB Integration Statistics (population counts by employment status)
#     |
#     v
# Filter: grounds for settlement × years in Sweden × total (region/sex/age)
#     |
#     v
# Calculate employment rate: (employed / total) × 100
#     |
#     v
# JSON export for Vega-Lite heat map
# ```
#
# ### Output Schema
# ```json
# [
#   {"category": "Labour migrants", "years_in_sweden": "0-3 yrs", "year": 2023, "employment_rate": 72.5},
#   {"category": "Refugees & relatives", "years_in_sweden": "0-3 yrs", "year": 2023, "employment_rate": 35.2},
#   ...
# ]
# ```
#
# ### Key Findings
# - **Labour migrants** have highest employment rates across all durations
# - **Refugees** start low but show convergence over time (10+ years)
# - Clear gradient visible: employment increases with years in Sweden for all groups
